# %%
import pandas as pd
import csv
import os
from collections import Counter
#import openpyxl
import re
import json

# %%
'''
read csv file load dataframe into memory
'''
path_to_file = '../hammoq_metadata_files/products.csv'

# %%
'''
if any element from keywords_list available in string_
return true
'''
def any_found(string_,keywords_list):
    return any(string in string_ for string in keywords_list)

# %%
'''
read products.csv file and fetch all matching cases for given keyword
'''
# Out:
# '\nread products.csv file and fetch all matching cases for given keyword\n'

# %%
keyword = 'top'

'''
keywords to include to include categories
'''
keywords_to_include = ['women','woman']
'''
keywords to exclude categories 
'''
keywords_to_exclude = ['shoe','sneaker','loafer','boot']

'''
columns from products dataframe to process
'''

imp_col=['productString','title','category','shortDescription','keywords']


def fetch_keyword_matching_products (products_df = products_df,
                                     keyword=keyword,imp_col=imp_col,
                                     keywords_to_include=keywords_to_include,
                                     keywords_to_exclude=keywords_to_exclude):
    
    prod_ids = []
    image_ids = []
    output=[]
    counter=0
    print(f'processing')
    for product in products_df['products']:
        for prod in json.loads(product):
            tmp_keys = prod.keys()
            '''
            pick common columns among imp_cols and prod.keys
            '''
            fnl_cols = set(imp_col).intersection(set(tmp_keys))
            fnl_cols = list(fnl_cols)
            string_ =''
            '''
            for all those columns pick strings and build one string
            '''
            for i in fnl_cols:
                string_ = string_+str(prod[i])
            string_ = string_.lower().replace('%20',' ').replace('%0a',' ').replace('%3a',' ')
            try:
                if keyword in string_ and any_found(string_,keywords_to_include) and not any_found(string_,keywords_to_exclude):

                    #prod_ids.append(prod['_id']['$oid'])
                    #print('done')
                    images = prod['images']
                    fnl_imgs = [v for k,v in images.items()]
                    #image_ids.append(fnl_imgs)
                    output.append({'prod_id':prod['_id']['$oid'],'images':fnl_imgs,'string':string_})
                    counter+=1

            except:
                print('skipped')
                pass

    print(f'match of {keyword} found in {counter} products')
    return output

# %%
'''
Input products.csv is big, around 4.6 gb
we need to parse in chunks
'''

big_data = pd.read_csv(path_to_file,chunksize=100)
data = []
while (1) :

    try:
        products_df = next(big_data,'end')
        for datum in fetch_keyword_matching_products(products_df=products_df):
            data.append(datum)
        
    except Exception as e:
        print(e)
        break
# Out:
# processing
# match of shirt found in 190 products
# processing
# match of shirt found in 762 products
# processing
# match of shirt found in 325 products
# processing
# match of shirt found in 438 products
# processing
# match of shirt found in 532 products
# processing
# match of shirt found in 279 products
# processing
# match of shirt found in 598 products
# processing
# match of shirt found in 595 products
# processing
# match of shirt found in 438 products
# processing
# match of shirt found in 337 products
# processing
# match of shirt found in 316 products
# processing
# match of shirt found in 255 products
# processing
# match of shirt found in 314 products
# processing
# match of shirt found in 196 products
# processing
# match of shirt found in 201 products
# processing
# match of shirt found in 89 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 23 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 19 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 19 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 18 products
# processing
# match of shirt found in 38 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 19 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 28 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 20 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 24 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 19 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 21 products
# processing
# match of shirt found in 22 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 28 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 27 products
# processing
# match of shirt found in 18 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 27 products
# processing
# match of shirt found in 21 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 19 products
# processing
# match of shirt found in 18 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 28 products
# processing
# match of shirt found in 21 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 16 products
# processing
# match of shirt found in 18 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 17 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 13 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 27 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 26 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 19 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 22 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 20 products
# processing
# match of shirt found in 23 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 15 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 11 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 20 products
# processing
# match of shirt found in 12 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 5 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 10 products
# processing
# match of shirt found in 14 products
# processing
# match of shirt found in 4 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 7 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 1 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 0 products
# processing
# match of shirt found in 9 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 2 products
# processing
# match of shirt found in 6 products
# processing
# match of shirt found in 8 products
# processing
# match of shirt found in 3 products
# processing
# match of shirt found in 3 products
# processing
# string indices must be integers

# %%
pd.DataFrame(data)
# Out:
#                        prod_id  \
# 0     5eec4431a2c31e26df430c78
# 1     5fd5a3add64f3b2cabd6f740
# 2     5fd9a6ef39a7bf6bd8611645
# 3     5f69d6472cbab809a574a252
# 4     5f8f70cba6d55065aba2f70a
# ...                        ...
# 9228  61de1dc010feeb08a185e037
# 9229  61de284fff97130425617f55
# 9230  61de5550ff9713042561db9e
# 9231  61de74993a49aa007358d227
# 9232  61de75da10feeb08a186dfbc
#
#                                                  images  \
# 0     [aaa7d5ac78736b139c98Screen Shot 2020-05-18 at...
# 1     [594f6c4aee6b9bc1048ablob, 54ee2069e9ee9e21107...
# 2     [25649e9a8f349be6b12cblob, 2884822097fb96931be...
# 3     [982cc84684c27203c6ecblob, 656ed1966f5a6037d0c...
# 4     [6145dfd48af773e7770ablob, 727dd38afdbabe9f9ce...
# ...                                                 ...
# 9228  [1641946415210-default_image.jpg, 164194641521...
# 9229  [1641949254423-20220111_184824.jpg, 1641949254...
# 9230  [1641960454632-default_image.jpg, 164196045463...
# 9231  [1641968723167-default_image.jpg, 164196872317...
# 9232  [1641968958076-default_image.jpg, 164196895807...
#
#                                                  string
# 0     womennike shirt\ncategory: women\ncolor: blue\...
# 1     womencaribbean mens gray blue plaid button up ...
# 2     womeneileen fisher mandarin collar shirt dress...
# 3     womencynthia rowley womens cotton silk shirt s...
# 4     womenlucky brand womens green camouflage stret...
# ...                                                 ...
# 9228  womenj crew womens green red plaid slim fit co...
# 9229  womenequipment femme womens cream long sleeve ...
# 9230  womenmeadow rue anthropologie womens ivory bri...
# 9231  womenpierre cardin womens yellow short sleeve ...
# 9232  womencherokee womens pink yellow white striped...
#
# [9233 rows x 3 columns]

# %%
pd.DataFrame(data).to_csv(f'../women_tops/historical_data_analysis/get_historical_images/output/csv/big_data_women_{keyword}_to_get.csv')
